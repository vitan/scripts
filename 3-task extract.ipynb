# %%
import re
from BeautifulSoup import BeautifulSoup

service = open('/home/weizhou/Projects/scripts/output/service', 'r')
fls = open('/home/weizhou/Projects/scripts/input/task/fls', 'r')
fls_service_inf = open('/home/weizhou/Projects/scripts/input/service/fls-service-slice-1', 'r')
lb_service = open('/home/weizhou/Projects/scripts/input/service/lb_for_3_task_extract', 'r')
lb_task = open('/home/weizhou/Projects/scripts/input/task/lb', 'r')

outf= open('/home/weizhou/Projects/scripts/output/task', 'w')

cr = open('/home/weizhou/Projects/scripts/input/service/cr', 'r')
cr_task = open('/home/weizhou/Projects/scripts/output/cr', 'r')


FILES = (service,
         fls,
         fls_service_inf,
         lb_service,
         lb_task,
         outf,
         )

# %%
#
# Get all the tasks
#

service_code_reg = re.compile(r'(FS|CR|LB)-[\d]{3}-[\d]{2}-[\d]{3}-v[\d]{1}')

#1	Engineering Operations - CORE
#2	Engineering Operations - LAB
#3	Engineering Operations - FLS
team_dict = {'CR': '1',
             'LB': '2',
             'FS': '3',
             'CA': '4',
             'SA': '5',
             'SE': '6',
             }

service_dict = dict()
for item in service:
    item = item.strip()
    for element in item.split('|')[1].split(' , '):
        service_dict[element] = item.split('|')[0]

current_service_id = None
task_dict = dict()

# FLS service process 1
fls_services = []
fls_row = fls_service_inf.read().strip()
# cleaned the boring noisy data
fls_services = fls_row.split(' | ')[1:-2]

# FLS task process
fls_content = fls.read()
fls_soup = BeautifulSoup(fls_content)
fls_tables = fls_soup.findAll('div', 'table-wrap')

#Process tables[1:-2]
if len(fls_services) != len(fls_tables)-3:
    raise Exception('ERROR: service can not be aligned to fls tables')
for fls_service, fls_table in zip(fls_services, fls_tables[1:-2]):
    current_service_id = service_dict[fls_service]

    trs = fls_table.table.tbody.findAll('tr')
    #Skip first line
    trs = trs[1:]
    for tr in trs:
        if tr.contents[0].string:
            if tr.contents[0].string == u'&nbsp;':
                continue
            code = tr.contents[0].string.strip()
        else:
            code = tr.contents[0].p.string.strip()
        if service_code_reg.match(code) is None:
            continue
        if tr.contents[1].string and tr.contents[1].string != u'&nbsp;':
            desc = tr.contents[1].string.strip()
        else:
            desc = 'NA'
        if tr.contents[2].a:
            link = tr.contents[2].a['href']
        else:
            link = 'NA'
        task_dict[code] = [current_service_id, 
                           team_dict[code.split('-')[0]] if code else'NA',
                           code.split('-')[3] if code else'NA',
                           desc,
                           link]

#Process tables[-2]
trs = fls_tables[-2].table.tbody.findAll('tr')
trs = trs[1:]
for tr in trs:
    if len(tr.contents) is not 4:
        raise Exception('ERROR FORMAT', line)
    fls_service = tr.td.string.strip()
    if fls_service and fls_service != u'&nbsp;':
        current_service_id = service_dict[fls_service]
    if tr.contents[1].string:
        if tr.contents[1].string == u'&nbsp;':
            continue
        code = tr.contents[1].string.strip()
    else:
        code = tr.contents[1].p.string.strip()
    if service_code_reg.match(code) is None:
        continue
    if tr.contents[2].string and tr.contents[2].string != u'&nbsp;':
        desc = tr.contents[2].string.strip()
    else:
        desc = 'NA'
    if tr.contents[3].a:
        link = tr.contents[3].a['href']
    else:
        link = 'NA'
    task_dict[code] = [current_service_id,
                       team_dict[code.split('-')[0]] if code else'NA',
                       code.split('-')[3] if code else'NA',
                       desc,
                       link]


#lb task process
for line in lb_service:
    row_list = line.split('\t')
    #LB table format
    #Service ID \t Service Name
    if len(row_list) is not 2:
        raise Exception('ERROR FORMAT', line)
    service_dict[row_list[0].split('-')[1]] = service_dict[row_list[1].strip()]

lb_content = lb_task.read()
lb_soup = BeautifulSoup(lb_content)
lb_tables = lb_soup.findAll('div', 'table-wrap')

#skip first 2table
lb_tables = lb_tables[2:]

for lb_table in lb_tables:
    trs = lb_table.tbody.findAll('tr')
    for tr in trs:
        if tr.contents[0].string:
            if tr.contents[0].string == u'&nbsp;':
                continue
            code = tr.contents[0].string.strip()
        else:
            continue
        if service_code_reg.match(code) is None:
            continue
        if tr.contents[1].string and tr.contents[1].string != u'&nbsp;':
            desc = tr.contents[1].string.strip()
        else:
            desc = 'NA'
        print tr.contents
        if tr.contents[5].a:
            link = tr.contents[5].a['href']
        else:
            link = 'NA'
        task_dict[code] = [service_dict[code.split('-')[1]], 
                           team_dict[code.split('-')[0]],
                           code.split('-')[3],
                           desc,
                           link]


'''
#CR task process
for line in cr_task:
    tds = line.strip().split('|')
    task_dict[tds[0]] = [service_dict[tds[1]],
                       tds[2],
                       tds[3],
                       tds[4] if tds[4].strip() else 'NA',
                       'NA',
                       ]
'''
# clean up
NO_MATCHING = 'NO MATCHING TASK AVAILABLE'
result = [item for item in task_dict.values() if item[3].strip() != NO_MATCHING]
count = xrange(0, len(result))
id_task = ["|%s|%s|" % (key+1, '|'.join(value)) for (key, value) in zip(count, result)]
outf.write("||ID||Service ID||Responsible Team ID||Cost||Description||Detail Link||\n" + str('\n'.join(id_task)))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-e577550d43c8> in <module>()
#     132             desc = 'NA'
#     133         print tr.contents
# --> 134         if tr.contents[5].a:
#     135             link = tr.contents[5].a['href']
#     136         else:
#
# IndexError: list index out of range
# [<td class="confluenceTd">LB-000-00-060-v1</td>, <td class="confluenceTd">Hands-on service provided</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-01-060-v1</td>, <td class="confluenceTd">Install/configure new rack</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-02-018-v1</td>, <td class="confluenceTd">Allocate lab space/power/networking</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-03-024-v1</td>, <td class="confluenceTd">Install/configure/label PDU</td>, <td class="confluenceTd">.4</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-04-030-v1</td>, <td class="confluenceTd">Rack/cable/label server / switch</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-05-012-v1</td>, <td class="confluenceTd">Configure server management 'iLO, DRAC, IMM</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-06-048-v1</td>, <td class="confluenceTd">DNS/DHCP/Conserver entries</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-07-012-v1</td>, <td class="confluenceTd">store/dispose of server packing materials</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-08-030-v1</td>, <td class="confluenceTd">Basic storage setup/configuration</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-09-120-v1</td>, <td class="confluenceTd">Advanced storage setup/configuration</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-10-060-v1</td>, <td class="confluenceTd">Re-rack server</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-11-048-v1</td>, <td class="confluenceTd">New Serial Driver to conserver</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-12-180-v1</td>, <td class="confluenceTd">Power outage preparation/recovery</td>, <td class="confluenceTd">3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-13-150-v1</td>, <td class="confluenceTd">Rack planning, evaluation and elevation</td>, <td class="confluenceTd">2.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-14-060-v1</td>, <td class="confluenceTd">Configure AMM for a new IBM Bladecenter</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-001-15-030-v1</td>, <td class="confluenceTd">activate software/Remote management license</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-002-01-060-v1</td>, <td class="confluenceTd">Evaluation license acquisition</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS could handle this.</td>, <td class="confluenceTd"><a href="/display/KB/VmWare+Licences">VmWare Licences</a></td>]
# [<td class="confluenceTd">LB-003-01-012-v1</td>, <td class="confluenceTd">Remove from beaker</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Remove+Beaker+Entry">Remove Beaker Entry</a></td>]
# [<td class="confluenceTd">LB-003-02-048-v1</td>, <td class="confluenceTd">Remove server configs</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-003-03-006-v1</td>, <td class="confluenceTd">Record serial number/name/model</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-003-04-042-v1</td>, <td class="confluenceTd">Remove hardware from rack</td>, <td class="confluenceTd">.7</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-003-05-042-v1</td>, <td class="confluenceTd">Remove confidential hardware(CPUs)/copper/eWaste components</td>, <td class="confluenceTd">.7</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-003-06-030-v1</td>, <td class="confluenceTd">Remove tap can</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-003-07-012-v1</td>, <td class="confluenceTd">Start or check DBAN progress</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-003-08-030-v1</td>, <td class="confluenceTd">Start or check custom HDD erase progress (e.g. erase coraids)</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-01-030-v1</td>, <td class="confluenceTd">Evaluate purchasing requirements and provide recommended hardware specifications</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-02-018-v1</td>, <td class="confluenceTd">Raise a PR/PRs in E-business suite and mark the status in the ticket</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS could support this task</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-03-012-v1</td>, <td class="confluenceTd">Check PR approval status in E-business suite every week or asked by the requestor and mark the status in the ticket</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td style="text-align: left;" class="confluenceTd">FLS could support this task</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-04-018-v1</td>, <td class="confluenceTd">Request lab space and create child racking ticket before getting PO</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS could support this task</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-05-012-v1</td>, <td class="confluenceTd">Get the PO created by Finance after the PR approved and send it to the vendor</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td style="text-align: left;" class="confluenceTd">FLS could support this task</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-06-018-v1</td>, <td class="confluenceTd">Confirm receiving in E-business suite and ask for payment invoice from the vendor then forward it to Finance</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-07-018-v1</td>, <td class="confluenceTd">Modify quote request per ticket discussion and request re-quote from vendor</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-08-018-v1</td>, <td class="confluenceTd">Request Import and Procurement Certificates template with Proforma Invoice</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">PNQ only</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-09-018-v1</td>, <td class="confluenceTd">Apply for Import and Procurement Certificates</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">PNQ only</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-10-012-v1</td>, <td class="confluenceTd">Inform vendor that ICPC is ready</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">PNQ only</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-11-012-v1</td>, <td class="confluenceTd">Collect shipment details from vendor and send it to STPI consultant</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">PNQ only</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-12-024-v1</td>, <td class="confluenceTd">Collect serial numbers and send it to STPI consultant</td>, <td class="confluenceTd">.6</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">PNQ only</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-13-012-v1</td>, <td class="confluenceTd">Assign MSDN subscription</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-14-012-v1</td>, <td class="confluenceTd">Request competing vendor quotes</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-004-15-060-v1</td>, <td class="confluenceTd">Low cost corporate card purchases from non-standard online vendors</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">Applies to purchases made outside of Oracle iProcurement</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">FS-004-16-030-v1</td>, <td class="confluenceTd">Extend trial license</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">FLS</td>, <td class="confluenceTd">Extend trial license</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-004-17-060-v1</td>, <td colspan="1" class="confluenceTd">Add a new supplier to Oracle</td>, <td colspan="1" class="confluenceTd">1</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-005-01-018-v1</td>, <td class="confluenceTd">Sign for and move hardware from shipping to staging room</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-005-02-030-v1</td>, <td class="confluenceTd">Verify order(Quote in RT against Packing Slip)</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-005-03-048-v1</td>, <td class="confluenceTd">Inspect (Packing Slip against received hardware) and document</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd"><a class="external-link" href="https://home.corp.redhat.com/wiki/hardware-receiving-checklist" rel="nofollow">Receiving checklist</a></td>]
# [<td class="confluenceTd">LB-005-04-018-v1</td>, <td class="confluenceTd">Update ticket(s)/File paperwork</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd"><a href="/display/KB/Hardware+Receiving+and+Installation+Procedures">Hardware Receiving and Installation Procedures</a></td>]
# [<td class="confluenceTd">LB-005-05-018-v1</td>, <td class="confluenceTd">Store system(s) until they can be racked</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-005-06-042-v1</td>, <td class="confluenceTd">Pack and ship out hardware (software)</td>, <td class="confluenceTd">.7</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-005-07-036-v1</td>, <td class="confluenceTd">Distribute workstations with help from facilities</td>, <td class="confluenceTd">.6</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-005-08-060-v1</td>, <td colspan="1" class="confluenceTd">Return/replace incompatible equipment</td>, <td colspan="1" class="confluenceTd">1</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-01-060-v1</td>, <td class="confluenceTd">Diagnose bad HDD</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-02-030-v1</td>, <td class="confluenceTd">PXE boot issue</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-03-120-v1</td>, <td class="confluenceTd">CPU error</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-04-060-v1</td>, <td class="confluenceTd">SPI board</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-05-120-v1</td>, <td class="confluenceTd">System not powering booting</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-06-090-v1</td>, <td class="confluenceTd">System unpingable</td>, <td class="confluenceTd">1.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-07-030-v1</td>, <td class="confluenceTd">Power cycle system</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-08-030-v1</td>, <td class="confluenceTd">Configure console output</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-09-030-v1</td>, <td class="confluenceTd">Reset BMC</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-10-030-v1</td>, <td class="confluenceTd">Check/verify vlan on switch</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-11-012-v1</td>, <td class="confluenceTd">Send outage email to inform impacted users</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-12-030-v1</td>, <td class="confluenceTd">Log service call on broken hardware</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-13-048-v1</td>, <td class="confluenceTd">New RAID configuration</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-14-006-v1</td>, <td class="confluenceTd">Format hdd (per disk)</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-15-012-v1</td>, <td class="confluenceTd">Reseated hardware</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-16-018-v1</td>, <td class="confluenceTd">CD drive problem</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-17-120-v1</td>, <td class="confluenceTd">Particular Distro Not Installing on System</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-18-018-v1</td>, <td class="confluenceTd">Bad memory replacement</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-19-012-v1</td>, <td class="confluenceTd">IPMI tool</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/IPMI+Tool">IPMI Tool</a></td>]
# [<td class="confluenceTd">LB-006-20-018-v1</td>, <td class="confluenceTd">reset root pwd</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Reset+root+pwd">Reset root pwd</a></td>]
# [<td class="confluenceTd">LB-006-21-018-v1</td>, <td class="confluenceTd">move I/O adapter</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-22-060-v1</td>, <td class="confluenceTd">research/reading documentation</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-23-360-v1</td>, <td class="confluenceTd">reconfigure Blade Center Switch</td>, <td class="confluenceTd">6</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-24-060-v1</td>, <td class="confluenceTd">monitor technician repairing hardware</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-25-060-v1</td>, <td class="confluenceTd">I/O adapter</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-006-26-030-v1</td>, <td class="confluenceTd">reset NVRAM/CMOS</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-006-27-030-v1</td>, <td colspan="1" class="confluenceTd">Open h/w service request with IBM</td>, <td colspan="1" class="confluenceTd">.5</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-006-28-030-v1</td>, <td colspan="1" class="confluenceTd">Check Warranty Status on Vendor Website</td>, <td colspan="1" class="confluenceTd">.5</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-01-048-v1</td>, <td class="confluenceTd">CPU installation/replacement</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-02-030-v1</td>, <td class="confluenceTd">Memory installation/replacement</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-03-030-v1</td>, <td class="confluenceTd">I/O card installation/replacement (NIC, RAID, etc)</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-04-030-v1</td>, <td class="confluenceTd">HDD/SSD installation/replacement</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-05-120-v1</td>, <td class="confluenceTd">BIOS/FW update</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-06-030-v1</td>, <td class="confluenceTd">Power supply replacement</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-07-120-v1</td>, <td class="confluenceTd">Main Board replacement</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td style="text-align: left;" class="confluenceTd">LB-007-08-048-v1</td>, <td class="confluenceTd">Create USB boot device</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-09-012-v1</td>, <td class="confluenceTd">Run inventory job again after hardware replacement</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Run+inventory+script">Run inventory script</a></td>]
# [<td class="confluenceTd">LB-007-10-030-v1</td>, <td class="confluenceTd">Locate replacement hw from inventory</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-11-018-v1</td>, <td class="confluenceTd">Fix hardware component (i.e. loose port, bent pin, etc.)</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-007-12-048-v1</td>, <td class="confluenceTd">Replace motherboard battery</td>, <td class="confluenceTd">.6</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-01-018-v1</td>, <td class="confluenceTd">change BIOS settings</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-02-018-v1</td>, <td class="confluenceTd">reset boot order</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Reset+boot+order">Reset boot order</a></td>]
# [<td class="confluenceTd">LB-008-03-030-v1</td>, <td class="confluenceTd">manual distro install</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-04-018-v1</td>, <td class="confluenceTd">test beaker power actions</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Test+power+commands">Test power commands</a></td>]
# [<td class="confluenceTd">LB-008-05-012-v1</td>, <td class="confluenceTd">activate LPAR partition</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-06-030-v1</td>, <td class="confluenceTd">modify storage LUNS/mapping</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-07-030-v1</td>, <td class="confluenceTd">console output</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-08-030-v1</td>, <td class="confluenceTd">download and add particular distro in pxe</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-09-030-v1</td>, <td class="confluenceTd">test access to system</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-10-060-v1</td>, <td class="confluenceTd">research/reading documentation</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-11-360-v1</td>, <td class="confluenceTd">IBM HMC rebuild</td>, <td class="confluenceTd">6</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-12-030-v1</td>, <td class="confluenceTd">Investigating/repairing Beaker server errors</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-13-030-v1</td>, <td class="confluenceTd">reset root password in single user mode</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-14-048-v1</td>, <td class="confluenceTd">analysing logs</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-15-030-v1</td>, <td class="confluenceTd">register machine with Intel Support</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-16-030-v1</td>, <td class="confluenceTd">download and burn CD/DVD image</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-17-030-v1</td>, <td class="confluenceTd">general scripting and automation</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-18-030-v1</td>, <td class="confluenceTd">Add/remove/configure yum repo</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-19-030-v1</td>, <td class="confluenceTd">Resize logical volumes and file systems</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd"><a href="/display/KB/Resizing+KVM+disk+images+on+LVM">Resize KVM with LVM</a></td>]
# [<td class="confluenceTd">LB-008-20-030-v1</td>, <td class="confluenceTd">configure ppc64 lpar from scratch</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-21-060-v1</td>, <td class="confluenceTd">install and configure vios</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-008-22-060-v1</td>, <td class="confluenceTd">troubleshoot DNS issues (past basic dig,host etc)</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-008-23-030-v1</td>, <td colspan="1" class="confluenceTd">File a Bugzilla request with supporting data</td>, <td colspan="1" class="confluenceTd">.5</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-011-39-024-v1</td>, <td colspan="1" class="confluenceTd">Clean-up disk space (Nagios alert)</td>, <td colspan="1" class="confluenceTd">.4</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-011-40-024-v1</td>, <td colspan="1" class="confluenceTd">Remove a VM from a KVM hypervisor (+remove lv)</td>, <td colspan="1" class="confluenceTd">.4</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-011-41-030-v1</td>, <td colspan="1" class="confluenceTd">Configure bond mode 0/1/2/3/4/5/6</td>, <td colspan="1" class="confluenceTd">.5</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-011-42-030-v1</td>, <td colspan="1" class="confluenceTd">Test / Troubleshoot / Crash via SysRq</td>, <td colspan="1" class="confluenceTd">.5</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-011-43-030-v1</td>, <td colspan="1" class="confluenceTd">Fix routing issues</td>, <td colspan="1" class="confluenceTd">.5</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">FS-009-01-045-v2</td>, <td class="confluenceTd">System loaned through beaker, monitored and returned as scheduled</td>, <td class="confluenceTd">.75</td>, <td style="text-align: center;" class="confluenceTd">FLS</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/System+loaned+through+beaker">System loaned through beaker</a></td>]
# [<td class="confluenceTd">FS-010-01-018-v1</td>, <td class="confluenceTd">create beaker entry</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Create+beaker+entry">Create beaker entry</a></td>]
# [<td class="confluenceTd">FS-010-02-006-v1</td>, <td class="confluenceTd">run inventory script</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Run+inventory+script">Run inventory script</a></td>]
# [<td class="confluenceTd">FS-010-03-006-v1</td>, <td class="confluenceTd">beaker provisioning</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Beaker+provisioning">Beaker provisioning</a></td>]
# [<td class="confluenceTd">FS-010-04-006-v1</td>, <td class="confluenceTd">machine test</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Machine+test">Machine test</a></td>]
# [<td class="confluenceTd">LB-010-05-018-v1</td>, <td class="confluenceTd">csv bulk update</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td style="text-align: center;" class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-06-060-v1</td>, <td class="confluenceTd">importing Distos (aka adding distro to PXE menu)</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td style="text-align: left;" class="confluenceTd"><a href="/display/KB/Importing+and+Removing+Beaker+Distros">Importing and Removing Beaker Distros</a></td>]
# [<td class="confluenceTd">FS-010-07-006-v1</td>, <td class="confluenceTd">managing groups</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Managing+groups">Managing groups</a></td>]
# [<td class="confluenceTd">FS-010-08-006-v1</td>, <td class="confluenceTd">managing users</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Managing+users">Managing users</a></td>]
# [<td class="confluenceTd">FS-010-09-006-v1</td>, <td class="confluenceTd">managing system inventory (change any single field)</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Managing+system+inventory">Managing system inventory</a></td>]
# [<td class="confluenceTd">FS-010-10-006-v1</td>, <td class="confluenceTd">managing task inventory</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Managing+task+inventory">Managing task inventory</a></td>]
# [<td class="confluenceTd">LB-010-12-030-v1</td>, <td class="confluenceTd">beaker stage/devel cfengine system configuration changes</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-13-018-v1</td>, <td class="confluenceTd">update harness repo</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-14-030-v1</td>, <td class="confluenceTd">add new power script</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-15-060-v1</td>, <td class="confluenceTd">update kickstart template (test on stage, apply to prod)</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-16-018-v1</td>, <td class="confluenceTd">switch Beaker hosts to different lab controller</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-17-006-v1</td>, <td class="confluenceTd">release system using Beaker cli</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-18-030-v1</td>, <td class="confluenceTd">create production database dump</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd"><a href="/display/KB/Beaker+production+database+notes">Beaker production database notes</a></td>]
# [<td class="confluenceTd">LB-010-19-006-v1</td>, <td class="confluenceTd">edit kickstart snippets</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-20-030-v1</td>, <td class="confluenceTd">Research snippets</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-21-015-v1</td>, <td class="confluenceTd">General questions about using Beaker</td>, <td class="confluenceTd">.25</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">FS-010-22-006-v1</td>, <td class="confluenceTd">managing job inventory</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Managing+job+inventory">Managing job inventory</a></td>]
# [<td class="confluenceTd">LB-010-23-060-v1</td>, <td class="confluenceTd">Troubleshoot beaker job failures</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-010-24-060-v1</td>, <td class="confluenceTd">Request ssl cert update from IT</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd"><p>&nbsp;</p></td>]
# [<td colspan="1" style="text-align: center;" class="confluenceTd">LB-010-25-060-v1</td>, <td colspan="1" class="confluenceTd">make/update and commit cfengine configuration files of stand-alone static NFS server system following exsiting roles and examples for beaker infrastructure use</td>, <td colspan="1" class="confluenceTd">1</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">Docs coming soon</td>]
# [<td colspan="1" class="confluenceTd">LB-010-26-060-v1</td>, <td colspan="1" class="confluenceTd">install/reinstall OS on stand-alone static NFS server system with kickstart files generated by CfGen, and toggle manul operations of cfengine after the installation</td>, <td colspan="1" class="confluenceTd">1</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">Docs coming soon</td>]
# [<td colspan="1" class="confluenceTd">LB-010-27-060-v1</td>, <td colspan="1" class="confluenceTd">apply customized partitioning schema (as softRAID, LVM) and cfengine roles changes for servers with different hardware specifications. (may need testing installation and troubleshooting)</td>, <td colspan="1" class="confluenceTd">1</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">Docs coming soon</td>]
# [<td class="confluenceTd">LB-011-01-018-v1</td>, <td class="confluenceTd">prep tap can</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-011-02-030-v1</td>, <td class="confluenceTd">install tap can</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-011-03-030-v1</td>, <td class="confluenceTd">evaluate power requirements</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-011-04-012-v1</td>, <td class="confluenceTd">cable trace</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-011-05-048-v1</td>, <td class="confluenceTd">run cables (whalebone)</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-011-06-018-v1</td>, <td class="confluenceTd">switch reconfiguration - submit IT ticket/relabel</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd"><a href="/display/KB/%28Draft%29+Requesting+switch+configuration">(Draft) Requesting switch configuration</a></td>]
# [<td class="confluenceTd">LB-011-07-030-v1</td>, <td class="confluenceTd">assessing user request feasibility, evaluating systems involved</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-011-08-120-v1</td>, <td class="confluenceTd">major network change, migration component</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# ...
# [<td class="confluenceTd">LB-013-03-006-v1</td>, <td class="confluenceTd">access to mgmt/chassis</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-013-04-006-v1</td>, <td class="confluenceTd">insert CD in server</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">FS-013-05-006-v1</td>, <td class="confluenceTd">general customer assistance</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/Triage+documentation">Triage documentation</a></td>]
# [<td class="confluenceTd">FS-013-06-030-v1</td>, <td class="confluenceTd">"automatically marked broken" / "problem reported for"</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="/display/KB/AMB+tickets">AMB tickets</a></td>]
# [<td class="confluenceTd">LB-013-07-006-v1</td>, <td class="confluenceTd">no specific work needed</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">FS-013-08-060-v1</td>, <td class="confluenceTd">lab access request</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd"><a href="https://confluence-eval.sa.eng.bne.redhat.com/confluence/display/KB/Lab+Access+request" class="external-link" rel="nofollow">Lab Access request</a></td>]
# [<td class="confluenceTd">LB-013-09-012-v1</td>, <td class="confluenceTd">requesting updates/additional information</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">FS-013-10-012-v1</td>, <td class="confluenceTd">create new tickets (such as a child ticket)</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">FS-013-11-012-v1</td>, <td colspan="1" class="confluenceTd"><p>ticket research (determine histories, freq of request, background on issues and tickets, etc)</p></td>, <td colspan="1" class="confluenceTd">.2</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">FLS</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">FS-013-12-006-v1</td>, <td colspan="1" class="confluenceTd">Incorrectly triage of ticket.</td>, <td colspan="1" class="confluenceTd">.1</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">FS-013-13-006-v1</td>, <td colspan="1" class="confluenceTd">Prerequisite work not completed or correct.</td>, <td colspan="1" class="confluenceTd">.1</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-01-012-v1</td>, <td class="confluenceTd">Add new host/change host settings</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">*</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-02-048-v1</td>, <td class="confluenceTd">Add new OS</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-03-120-v1</td>, <td class="confluenceTd">Add new puppet module</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-04-030-v1</td>, <td class="confluenceTd">Change provisioning template</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-05-012-v1</td>, <td class="confluenceTd">Add/configure user/role</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">*</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-06-012-v1</td>, <td class="confluenceTd">Add/configure subnets/domains/architectures/hostgroup</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-07-060-v1</td>, <td class="confluenceTd">Maintenance/upgrade</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-014-08-060-v1</td>, <td class="confluenceTd">Reprovision host</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-01-018-v1</td>, <td class="confluenceTd">Create/expose &amp; remove luns</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-02-018-v1</td>, <td class="confluenceTd">Create/expose &amp; remove NFS/CIFS shares</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-03-030-v1</td>, <td class="confluenceTd">Licensing</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-04-060-v1</td>, <td class="confluenceTd">Snapmirror/sync/backup</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-05-012-v1</td>, <td class="confluenceTd">Permissions</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">*</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-06-012-v1</td>, <td class="confluenceTd">Add/configure user/role</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">*</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-07-030-v1</td>, <td class="confluenceTd">Vfilers creation/config</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-08-012-v1</td>, <td class="confluenceTd">Snapshots creation/removal</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-09-030-v1</td>, <td class="confluenceTd">FC cabling/switches configuration</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-10-060-v1</td>, <td class="confluenceTd">Network/service configuration</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-11-120-v1</td>, <td class="confluenceTd">Maintenance/troubleshooting</td>, <td class="confluenceTd">2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-015-12-012-v1</td>, <td class="confluenceTd">Volume/aggregate changes</td>, <td class="confluenceTd">0.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-01-018-v1</td>, <td class="confluenceTd">add/remove/rename VMs</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">*</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-02-090-v1</td>, <td class="confluenceTd">add hypervisors</td>, <td class="confluenceTd">1.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-03-396-v1</td>, <td class="confluenceTd">hypervisors/rhevm periodical maintenance</td>, <td class="confluenceTd">6.6</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-04-018-v1</td>, <td class="confluenceTd">Permissions</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">*</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-05-048-v1</td>, <td class="confluenceTd">Configure the data/export storages</td>, <td class="confluenceTd">.8</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-06-030-v1</td>, <td class="confluenceTd">Take a snapshot</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-07-018-v1</td>, <td class="confluenceTd">Export a VM</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-08-006-v1</td>, <td class="confluenceTd">Start/stop VM</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-09-018-v1</td>, <td class="confluenceTd">Add/remove resources from a VM</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-10-180-v1</td>, <td class="confluenceTd">RHEVM user-portal/Web Administration is unavailable</td>, <td class="confluenceTd">3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-016-11-006-v1</td>, <td class="confluenceTd">Create/change a user account</td>, <td class="confluenceTd">.1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td colspan="1" class="confluenceTd">LB-016-12-018-v1</td>, <td colspan="1" class="confluenceTd">Migrate a VM</td>, <td colspan="1" class="confluenceTd">.3</td>, <td colspan="1" style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>, <td colspan="1" class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-01-030-v1</td>, <td class="confluenceTd">Data Base support</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-02-018-v1</td>, <td class="confluenceTd">Database Backup</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-03-060-v1</td>, <td class="confluenceTd">Install A New Service Pack</td>, <td class="confluenceTd">1</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td style="text-align: left;" class="confluenceTd"><a class="external-link" href="https://docspace.corp.redhat.com/docs/DOC-30275" rel="nofollow"><span class="icon">&nbsp;</span>Installation</a></td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-04-018-v1</td>, <td class="confluenceTd">Troubleshooting: Software XY does not work on Jenkins slave Z</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-05-018-v1</td>, <td class="confluenceTd">Troubleshooting: Cannot delete files XY on Window Jenkins slave Z</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-06-018-v1</td>, <td class="confluenceTd">Troubleshooting: Node XY down in <br /> QA MW {cluster,messaging,perf} lab (hands-on needed)</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-07-030-v1</td>, <td class="confluenceTd">Troubleshooting: Node XY failing with file too large exception</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-08-030-v1</td>, <td class="confluenceTd">Troubleshooting: Jenkins slave XY marked as "Dead!"</td>, <td class="confluenceTd">.5</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">&nbsp;</td>, <td class="confluenceTd">&nbsp;</td>]
# [<td class="confluenceTd">LB-017-09-012-v1</td>, <td class="confluenceTd">Reboot Jenkins slave and re-attach it to the Jenkins grid</td>, <td class="confluenceTd">.2</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td class="confluenceTd">FLS eligible</td>, <td class="confluenceTd"><a href="/pages/viewpage.action?pageId=11370570">Jenkins - Shutdown/Reboot Jenkins Slave and reattach slave</a></td>]
# [<td class="confluenceTd">LB-017-10-018-v1</td>, <td class="confluenceTd">Troubleshooting: Cannot ssh/rdesktop to Jenkins slave XY as user Z</td>, <td class="confluenceTd">.3</td>, <td style="text-align: center;" class="confluenceTd">Labs</td>, <td colspan="2" class="confluenceTd">&nbsp;</td>]

# %%
for F in FILES:
    F.close()
